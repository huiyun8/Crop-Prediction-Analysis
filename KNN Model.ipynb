# %%
import pandas as pd
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import GridSearchCV
from sklearn.preprocessing import MinMaxScaler
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import plotly.graph_objects as go
import plotly.express as px
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# %% [markdown]
# # Load Data

# %%
dataset = pd.read_csv("Crop_recommendation.csv")

# %% [markdown]
# # Data Processing

# %% [markdown]
# 1. Check datatype to see if conversion needed

# %%
dataset.dtypes
# Out:
# N                int64
# P                int64
# K                int64
# temperature    float64
# humidity       float64
# ph             float64
# rainfall       float64
# label           object
# dtype: object

# %% [markdown]
# 2. Drop duplicates based on all columns

# %%
dataset.drop_duplicates(inplace=True)

# %% [markdown]
# 3. Split dataset into training and testing sets

# %%
X, y = dataset.iloc[:, :-1], dataset.iloc[:, -1]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %% [markdown]
# 4. Normalize the training and testing feature matrix

# %%
scaler = MinMaxScaler()
X_train_norm = scaler.fit_transform(X_train)
X_test_norm = scaler.transform(X_test)

# %% [markdown]
# # Model Training

# %%
# Train a k-NN classifier with normalized features
#k = 1 # set the number of neighbors
#clf = KNeighborsClassifier(metric='manhattan', n_neighbors=4, weights='distance')
clf = KNeighborsClassifier()
clf.fit(X_train_norm, y_train)

# Predict the labels for the training and test sets
y_train_pred = clf.predict(X_train_norm)
y_test_pred = clf.predict(X_test_norm)

# %%
score = cross_val_score(clf,X,y,cv=5)
print('Cross validation score: ',score)
# Out:
# Cross validation score:  [0.97727273 0.98181818 0.97954545 0.97954545 0.97954545]

# %%
from sklearn.metrics import accuracy_score

# Calculate the accuracy of the model on the training set
train_acc = accuracy_score(y_train, y_train_pred)
print("Training accuracy:", train_acc)

# Calculate the accuracy of the model on the test set
test_acc = accuracy_score(y_test, y_test_pred)
print("Testing accuracy:", test_acc)
# Out:
# Training accuracy: 0.9869318181818182
# Testing accuracy: 0.9863636363636363

# %% [markdown]
# # Hyperparameters Tuning

# %%
from sklearn import metrics

mean_accuracy = np.zeros(20)
for i in range(1,21):
    #Train Model and Predict  
    knn = KNeighborsClassifier(n_neighbors = i).fit(X_train,y_train)
    yhat= knn.predict(X_test)
    mean_accuracy[i-1] = metrics.accuracy_score(y_test, yhat)

mean_accuracy
# Out:
# array([0.98863636, 0.98181818, 0.98636364, 0.97954545, 0.98409091,
#        0.98181818, 0.98409091, 0.98409091, 0.97727273, 0.97727273,
#        0.97727273, 0.975     , 0.97272727, 0.97045455, 0.97272727,
#        0.96590909, 0.975     , 0.96818182, 0.96818182, 0.96590909])

# %%
loc = np.arange(1,21,step=1.0)
plt.figure(figsize = (10, 6))
plt.plot(range(1,21), mean_accuracy, color='brown')
plt.xticks(loc)
plt.xlabel('Number of Neighbors ')
plt.ylabel('Accuracy')
plt.show()

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.neighbors import KNeighborsClassifier


knn = KNeighborsClassifier()

param_grid = {'n_neighbors': [3, 5, 7, 9, 11], 'weights': ['uniform', 'distance'], 'metric': ['euclidean', 'manhattan']}
grid_search = GridSearchCV(knn, param_grid=param_grid, cv=5)
grid_search.fit(X_train, y_train)

print("Best hyperparameters: ", grid_search.best_params_)
print("Best accuracy score: ", grid_search.best_score_)
# Out:
# Best hyperparameters:  {'metric': 'manhattan', 'n_neighbors': 7, 'weights': 'distance'}
# Best accuracy score:  0.9818181818181818

# %%
# Using the best hyperparameters
knn_1 = KNeighborsClassifier(n_neighbors = 7, weights = 'distance',metric = 'manhattan')
knn_1.fit(X_train, y_train)
# Out:
# KNeighborsClassifier(metric='manhattan', n_neighbors=7, weights='distance')

# %%
# Training & Testing accuracy after applying hyper parameter
knn_train_accuracy = knn_1.score(X_train,y_train)
print("knn_train_accuracy = ",knn_1.score(X_train,y_train))
#Print Test Accuracy
knn_test_accuracy = knn_1.score(X_test,y_test)
print("knn_test_accuracy = ",knn_1.score(X_test,y_test))
# Out:
# knn_train_accuracy =  1.0
# knn_test_accuracy =  0.9886363636363636

# %% [markdown]
# # Evaluation

# %% [markdown]
# ###### Accuracy

# %%
# Evaluate the accuracy of the classifier on the training and test sets
from sklearn.metrics import accuracy_score
train_accuracy = accuracy_score(y_train, y_train_pred)
test_accuracy = accuracy_score(y_test, y_test_pred)

print("Training Accuracy:", train_accuracy)
print("Testing Accuracy:", test_accuracy)
# Out:
# Training Accuracy: 0.9869318181818182
# Testing Accuracy: 0.9863636363636363

# %% [markdown]
# ##### Confusion Matrix

# %%
from sklearn.metrics import confusion_matrix, classification_report

# %%
# Confusion matrix for test data
cm_test = confusion_matrix(y_test, y_test_pred)
f, ax = plt.subplots(figsize=(7.5,5))
sns.heatmap(cm_test, annot=True, linewidth=0.5, fmt=".0f",cmap='magma', ax = ax)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Predicted vs actual')
plt.show()

# %% [markdown]
# ##### 2. Classification Report
#
# Precision, recall, and F1-Score

# %%
# Classification report for test data
cr_test = classification_report(y_test, y_test_pred)
print("Classification Report:\n", cr_test)
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#        apple       1.00      1.00      1.00        25
#       banana       1.00      1.00      1.00        21
#    blackgram       0.89      1.00      0.94        17
#     chickpea       1.00      1.00      1.00        17
#      coconut       1.00      1.00      1.00        14
#       coffee       1.00      0.96      0.98        24
#       cotton       1.00      1.00      1.00        25
#       grapes       1.00      1.00      1.00        17
#         jute       0.95      1.00      0.98        20
#  kidneybeans       0.95      1.00      0.98        20
#       lentil       1.00      0.90      0.95        21
#        maize       1.00      1.00      1.00        24
#        mango       0.95      1.00      0.97        19
#    mothbeans       0.95      0.95      0.95        19
#     mungbean       1.00      1.00      1.00        17
#    muskmelon       1.00      1.00      1.00        16
#       orange       1.00      1.00      1.00        13
#       papaya       1.00      1.00      1.00        28
#   pigeonpeas       1.00      0.90      0.95        21
#  pomegranate       1.00      1.00      1.00        19
#         rice       1.00      1.00      1.00        21
#   watermelon       1.00      1.00      1.00        22
#
#     accuracy                           0.99       440
#    macro avg       0.99      0.99      0.99       440
# weighted avg       0.99      0.99      0.99       440

# %% [markdown]
# # Saving Model for Testing

# %% [markdown]
# ##### Pickle approach

# %%
import pickle

# %%
# Save the Model to file in the current working directory

Pkl_Filename = "Pickle_KNN_Model.pkl"  

with open(Pkl_Filename, 'wb') as file:  
    pickle.dump(knn_1, file)

# %%
# Load the Model back from file
with open(Pkl_Filename, 'rb') as file:  
    Pickled_KNN_Model = pickle.load(file)

Pickled_KNN_Model
# Out:
# KNeighborsClassifier(metric='manhattan', n_neighbors=7, weights='distance')

# %%
# Use the Reloaded Model to 
# Calculate the accuracy score and predict target values

# Calculate the Score 
score = Pickled_KNN_Model.score(X_test, y_test)  
# Print the Score
print("Test score: {0:.2f} %".format(100 * score))  

# Predict the Labels using the reloaded Model
Ypredict = Pickled_KNN_Model.predict(X_test)  

Ypredict
# Out:
# Test score: 98.64 %
# array(['muskmelon', 'pomegranate', 'kidneybeans', 'lentil', 'banana',
#        'lentil', 'kidneybeans', 'orange', 'lentil', 'pigeonpeas', 'apple',
#        'grapes', 'orange', 'pomegranate', 'coconut', 'pigeonpeas',
#        'orange', 'rice', 'cotton', 'mango', 'pigeonpeas', 'apple',
#        'pomegranate', 'kidneybeans', 'grapes', 'chickpea', 'apple',
#        'orange', 'mungbean', 'mothbeans', 'muskmelon', 'maize', 'coffee',
#        'chickpea', 'rice', 'banana', 'grapes', 'mothbeans', 'lentil',
#        'lentil', 'lentil', 'blackgram', 'rice', 'blackgram', 'cotton',
#        'pigeonpeas', 'pigeonpeas', 'cotton', 'maize', 'rice', 'orange',
#        'mothbeans', 'cotton', 'watermelon', 'grapes', 'chickpea',
#        'mungbean', 'coffee', 'banana', 'chickpea', 'orange', 'mungbean',
#        'pomegranate', 'mungbean', 'banana', 'banana', 'pigeonpeas',
#        'blackgram', 'grapes', 'mungbean', 'coconut', 'mothbeans', 'mango',
#        'pomegranate', 'chickpea', 'cotton', 'blackgram', 'lentil',
#        'maize', 'kidneybeans', 'cotton', 'coconut', 'cotton', 'blackgram',
#        'watermelon', 'kidneybeans', 'jute', 'orange', 'kidneybeans',
#        'kidneybeans', 'lentil', 'lentil', 'mothbeans', 'pomegranate',
#        'blackgram', 'apple', 'blackgram', 'grapes', 'watermelon',
#        'orange', 'lentil', 'apple', 'banana', 'apple', 'grapes', 'orange',
#        'mango', 'mungbean', 'watermelon', 'maize', 'pomegranate', 'mango',
#        'blackgram', 'cotton', 'kidneybeans', 'rice', 'mungbean',
#        'muskmelon', 'mothbeans', 'pomegranate', 'cotton', 'chickpea',
#        'mango', 'banana', 'grapes', 'apple', 'orange', 'pomegranate',
#        'jute', 'orange', 'cotton', 'chickpea', 'rice', 'orange', 'coffee',
#        'orange', 'apple', 'coffee', 'orange', 'pigeonpeas', 'cotton',
#        'kidneybeans', 'mothbeans', 'pomegranate', 'coconut', 'mothbeans',
#        'pigeonpeas', 'jute', 'coffee', 'rice', 'rice', 'grapes',
#        'pigeonpeas', 'muskmelon', 'blackgram', 'coconut', 'cotton',
#        'grapes', 'watermelon', 'grapes', 'chickpea', 'watermelon',
#        'mango', 'grapes', 'mothbeans', 'grapes', 'mothbeans', 'mango',
#        'grapes', 'muskmelon', 'lentil', 'coffee', 'mothbeans',
#        'kidneybeans', 'rice', 'watermelon', 'muskmelon', 'cotton',
#        'coffee', 'watermelon', 'kidneybeans', 'orange', 'mungbean',
#        'mothbeans', 'coconut', 'jute', 'chickpea', 'papaya', 'mango',
#        'banana', 'muskmelon', 'maize', 'jute', 'rice', 'mango', 'cotton',
#        'apple', 'grapes', 'mango', 'watermelon', 'kidneybeans', 'mango',
#        'muskmelon', 'papaya', 'coconut', 'orange', 'coconut', 'apple',
#        'chickpea', 'pomegranate', 'cotton', 'chickpea', 'muskmelon',
#        'pigeonpeas', 'cotton', 'papaya', 'papaya', 'pigeonpeas',
#        'kidneybeans', 'pigeonpeas', 'mothbeans', 'apple', 'cotton',
#        'watermelon', 'rice', 'cotton', 'mango', 'cotton', 'cotton',
#        'maize', 'pomegranate', 'watermelon', 'coffee', 'chickpea',
#        'lentil', 'coconut', 'jute', 'jute', 'jute', 'coconut', 'mango',
#        'mothbeans', 'chickpea', 'kidneybeans', 'watermelon', 'apple',
#        'maize', 'orange', 'papaya', 'mungbean', 'pigeonpeas',
#        'kidneybeans', 'apple', 'maize', 'mango', 'banana', 'coconut',
#        'pigeonpeas', 'banana', 'pomegranate', 'maize', 'coconut', 'mango',
#        'jute', 'papaya', 'banana', 'coffee', 'lentil', 'mungbean',
#        'chickpea', 'lentil', 'orange', 'papaya', 'muskmelon', 'lentil',
#        'mango', 'banana', 'mothbeans', 'watermelon', 'chickpea', 'coffee',
#        'lentil', 'orange', 'chickpea', 'maize', 'mango', 'jute', 'papaya',
#        'coconut', 'muskmelon', 'pomegranate', 'mango', 'coffee',
#        'watermelon', 'watermelon', 'mango', 'coffee', 'cotton', 'lentil',
#        'grapes', 'mungbean', 'jute', 'maize', 'grapes', 'rice',
#        'watermelon', 'apple', 'kidneybeans', 'mango', 'watermelon',
#        'watermelon', 'muskmelon', 'pigeonpeas', 'pigeonpeas', 'muskmelon',
#        'grapes', 'cotton', 'papaya', 'pomegranate', 'orange', 'mothbeans',
#        'papaya', 'cotton', 'muskmelon', 'maize', 'kidneybeans', 'coconut',
#        'chickpea', 'chickpea', 'mango', 'pomegranate', 'banana',
#        'mungbean', 'mungbean', 'rice', 'maize', 'coffee', 'cotton',
#        'chickpea', 'muskmelon', 'kidneybeans', 'chickpea', 'mothbeans',
#        'jute', 'pomegranate', 'chickpea', 'blackgram', 'banana',
#        'blackgram', 'orange', 'pigeonpeas', 'mungbean', 'blackgram',
#        'orange', 'coffee', 'mango', 'coconut', 'chickpea', 'maize',
#        'coffee', 'banana', 'jute', 'banana', 'chickpea', 'mothbeans',
#        'chickpea', 'blackgram', 'coffee', 'blackgram', 'apple',
#        'pigeonpeas', 'jute', 'muskmelon', 'mungbean', 'jute', 'maize',
#        'mango', 'rice', 'coconut', 'jute', 'papaya', 'grapes',
#        'kidneybeans', 'maize', 'jute', 'chickpea', 'orange', 'chickpea',
#        'muskmelon', 'mothbeans', 'apple', 'pigeonpeas', 'lentil',
#        'pigeonpeas', 'apple', 'lentil', 'pomegranate', 'apple',
#        'pigeonpeas', 'chickpea', 'apple', 'lentil', 'muskmelon', 'coffee',
#        'apple', 'papaya', 'mothbeans', 'lentil', 'orange', 'papaya',
#        'mungbean', 'maize', 'mothbeans', 'maize', 'papaya', 'papaya',
#        'banana', 'chickpea', 'jute', 'banana', 'jute', 'mango', 'coffee',
#        'rice', 'rice', 'jute', 'orange', 'rice', 'pomegranate',
#        'pomegranate', 'chickpea', 'jute', 'watermelon', 'watermelon',
#        'jute', 'rice', 'coconut', 'maize', 'coffee', 'lentil'],
#       dtype=object)
